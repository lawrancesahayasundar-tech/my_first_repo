# %% [markdown]
# <a href="https://colab.research.google.com/github/lawrancesahayasundar-tech/my_first_repo/blob/main/Lawrence_stage3_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Stage 3 – Student Grade Calculator

name = input("Enter student name: ")

m1 = float(input("Enter mark for subject 1: "))
m2 = float(input("Enter mark for subject 2: "))
m3 = float(input("Enter mark for subject 3: "))

total = m1 + m2 + m3
percentage = (total / 300) * 100

# Grade calculation
if percentage >= 75:
    grade = "A"
elif percentage >= 60:
    grade = "B"
elif percentage >= 40:
    grade = "C"
else:
    grade = "F"

# Output
print("\n", name)
print("Total:", total, "/300")
print("Percentage:", percentage, "%")
print("Grade:", grade)
# Out:
# Enter student name: Raj
# Enter mark for subject 1: 80
# Enter mark for subject 2: 70
# Enter mark for subject 3: 90
#
#  Raj
# Total: 240.0 /300
# Percentage: 80.0 %
# Grade: A
